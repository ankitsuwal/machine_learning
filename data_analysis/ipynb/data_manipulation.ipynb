# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# to knowing dtype is more important for performing some tasks
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes == "object"
a = titanic_train.dtypes[titanic_train.dtypes == "object"].index
print(a)
titanic_train[a].describe()
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')
#                                      Name   Sex      Ticket        Cabin  \
# count                                 156   156         156           31
# unique                                156     2         145           28
# top     Andersson, Miss. Ellis Anna Maria  male  W./C. 6608  C23 C25 C27
# freq                                    1   100           2            2
#
#        Embarked
# count       155
# unique        3
# top           S
# freq        110

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.dtypes[titanic_train.dtypes == 'int64'].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
# To extract data using column names
titanic_train[['Name', 'Sex', 'Age', 'Embarked', ]].head(10)
# Out:
#                                                 Name     Sex   Age Embarked
# 0                            Braund, Mr. Owen Harris    male  22.0        S
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0        C
# 2                             Heikkinen, Miss. Laina  female  26.0        S
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0        S
# 4                           Allen, Mr. William Henry    male  35.0        S
# 5                                   Moran, Mr. James    male   NaN        Q
# 6                            McCarthy, Mr. Timothy J    male  54.0        S
# 7                     Palsson, Master. Gosta Leonard    male   2.0        S
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0        S
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0        C

# %%
# If you are trying to extract data with column it's data type will se "series"
# titanic_train['Name']
type(titanic_train["Name"])
# if you want sorted data then
sorted(titanic_train["Name"])
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
# ...

# %%
"""and if you want to extract data with indexes"""
# (sorted(titanic_train["Name"]))[0:5] 
# you can also do step by step using [lowerbound:upperbound:steps]
(sorted(titanic_train["Name"]))[0:100:5] 
# you can also [100:0:-3], [:: -1]
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Attalah, Miss. Malake',
#  'Beesley, Mr. Lawrence',
#  'Burke, Mr. Jeremiah',
#  'Celotti, Mr. Francesco',
#  'Connors, Mr. Patrick',
#  'Devaney, Miss. Margaret Delia',
#  'Emir, Mr. Farred Chehab',
#  'Fortune, Mr. Charles Alexander',
#  'Glynn, Miss. Mary Agatha',
#  'Gustafsson, Mr. Anders Vilhelm',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Ilett, Miss. Bertha',
#  'Kantor, Mr. Sinai',
#  'Madsen, Mr. Fridtjof Arne',
#  'McGowan, Miss. Anna "Annie"',
#  'Moen, Mr. Sigurd Hansen',
#  'Moubarek, Master. Gerios',
#  'Newsom, Miss. Helen Monypeny']

# %%
# YOU CAN ALSO PERFORM OPERATION ON DATAFRAME
titanic_train[['Name']][0:10]
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James
# 6                            McCarthy, Mr. Timothy J
# 7                     Palsson, Master. Gosta Leonard
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                Nasser, Mrs. Nicholas (Adele Achem)

# %%
# you can create new column as well
# titanic_train["NewCloumn"] = 'ATS'

# if you want to update exist column than
# titanic_train["Cabin"] = 55

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# let see to update value in column
# titanic_train['Name'][0] = 'ankit suwal'

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_Pclass = pd.Categorical(titanic_train["Pclass"])

new_Pclass
# It is showing how many distinct data I have 3 distinct data and type[1, 2, 3]
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
# if you want to replace the data 
a = pd.Categorical(titanic_train["Pclass"])

# %%
a.rename_categories(['x', 'y', 'z'])
# Out:
# ['z', 'x', 'z', 'x', 'z', ..., 'x', 'z', 'z', 'z', 'x']
# Length: 156
# Categories (3, object): ['x', 'y', 'z']

# %%
# you can also replace with meaning full value
a.rename_categories(['class1', 'class2', 'class3'])
# Out:
# ['class3', 'class1', 'class3', 'class1', 'class3', ..., 'class1', 'class3', 'class3', 'class3', 'class1']
# Length: 156
# Categories (3, object): ['class1', 'class2', 'class3']

# %% [markdown]
# ### Q in your mind if we have 1000 of dictinct data then?
# ### ans: you can but not recomnded

# %%
# titanic_train
b = a.rename_categories(['class1', 'class2', 'class3'])
b
titanic_train['new_column'] = b
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# find unique values
# titanic_train['Name'].unique()
titanic_train['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
char_cabin = titanic_train['Cabin'].astype(str)
# for i in char_cabin:
#     print(i[0])
char_cabin1 = [cab[0] for cab in char_cabin]
char_cabin1
# Out:
# ['n',
#  'C',
#  'n',
#  'C',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'G',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'A',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'A',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'E',
#  'D',
# ...

# %%
char_cabin1 = np.array([cab[0] for cab in char_cabin])
char_cabin1 = pd.Categorical(char_cabin1)
char_cabin1
char_cabin1.describe()
# it is showing me count of characters
# Out:
#             counts     freqs
# categories
# A                2  0.012821
# B                5  0.032051
# C               10  0.064103
# D                6  0.038462
# E                3  0.019231
# F                4  0.025641
# G                1  0.006410
# n              125  0.801282

# %%
titanic_train["Age"].isnull() 
# series provide us indexes with value and list can only provide values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
missing = np.where(titanic_train["Age"].isnull() == True)
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154]),)

# %%
len(missing[0])
# Out:
# 30

# %%
titanic_train.loc[missing]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
index = np.where(titanic_train['Fare'] == max(titanic_train['Fare']))
print(index)
titanic_train.loc[index]
# Out:
# (array([27, 88]),)
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked new_column
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S     class1
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S     class1

# %%
max(titanic_train["Fare"])
# Out:
# 263.0

# %%
titanic_train["Family"] = titanic_train["SibSp"] + titanic_train["Parch"]
titanic_train["Family"]
most_family = np.where(titanic_train["Family"] == max(titanic_train["Family"]))
most_family
titanic_train.loc[most_family]
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 71           72         0       3          Goodwin, Miss. Lillian Amy  female
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked new_column  Family
# 59  11.0      5      2  CA 2144  46.9   NaN        S     class3       7
# 71  16.0      5      2  CA 2144  46.9   NaN        S     class3       7
